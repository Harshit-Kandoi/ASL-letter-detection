# %%
import requests
import zipfile
import os

# Dataset download URL
dataset_url = "https://public.roboflow.com/ds/GUynfsBiHu?key=mSHOdVa00b"

# Create a folder for the dataset
dataset_dir = "dataset"
os.makedirs(dataset_dir, exist_ok=True)

# Download the dataset
response = requests.get(dataset_url)
zip_path = os.path.join(dataset_dir, "dataset.zip")
with open(zip_path, "wb") as f:
    f.write(response.content)

# Extract the dataset
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(dataset_dir)

print(f"Dataset extracted to {dataset_dir}")
# Out:
# Dataset extracted to dataset

# %%
import os

# Check train and validation paths
train_path = "dataset/train/images"
val_path = "dataset/valid/images"

print(f"Train path exists: {os.path.exists(train_path)}")
print(f"Validation path exists: {os.path.exists(val_path)}")
# Out:
# Train path exists: True
# Validation path exists: True

# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\kando\Desktop\project

# %%
import torch
torch.cuda.empty_cache()

# %%
from ultralytics import YOLO
model = YOLO("yolov5su.pt")  # Or yolov11n.pt, yolov8s.pt etc.
data_config = "dataset/data.yaml"  # Path to your data.yaml file
# Train the model
model.train(data=data_config, epochs=50, imgsz=416)
# Out:
# New https://pypi.org/project/ultralytics/8.3.103 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.102  Python-3.10.16 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
import cv2
from ultralytics import YOLO

# Load trained model
model = YOLO("runs/detect/train36/weights/best.pt")

# Open webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Perform inference
    results = model(frame)

    # Visualize results
    annotated_frame = results[0].plot()

    # Display the frame
    cv2.imshow("Hand Sign Detection", annotated_frame)

    # Break loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 25.1ms
# Speed: 4.8ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.8ms
# Speed: 1.8ms preprocess, 15.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 1.7ms preprocess, 14.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.0ms
# Speed: 2.3ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.8ms
# Speed: 1.5ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.4ms
# Speed: 1.8ms preprocess, 13.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
